# %%
import os, random
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping
from ta.momentum import RSIIndicator

# Set random seeds for reproducibility
seed = 42
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
import tensorflow as tf
tf.random.set_seed(seed)

# Download AAPL data with extended window
df = yf.download("AAPL", start="2018-01-01", end="2025-08-01")

# Ensure Close column is float and properly shaped
df['Close'] = df['Close'].astype(float)

# Add indicators safely
df['RSI'] = RSIIndicator(close=pd.Series(df['Close'].values.flatten(), index=df.index), window=14).rsi()
df['SMA_5'] = df['Close'].rolling(window=5).mean()

# Drop rows with NaNs from indicators
df.dropna(inplace=True)

# Check if we still have usable data
if df.empty:
    raise ValueError("DataFrame is empty after adding indicators and dropping NaNs.")

# Define features and target
features = ['Open', 'High', 'Low', 'Volume', 'RSI', 'SMA_5']
target = 'Close'
X = df[features].values
y = df[target].values.reshape(-1, 1)

# Normalize features and target
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Train/test split
split = int(0.8 * len(X_scaled))
X_train, X_test = X_scaled[:split], X_scaled[split:]
y_train, y_test = y_scaled[:split], y_scaled[split:]

# Build the ANN model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(1)
])
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mse')

# Early stopping to prevent overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=200,
    batch_size=16,
    callbacks=[early_stop],
    verbose=0  # set to 1 to show training logs
)

# Predict and reverse normalization
y_pred_scaled = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_actual = scaler_y.inverse_transform(y_test)

# Evaluation
rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
r2 = r2_score(y_actual, y_pred)
print(f"ANN with Indicators - RMSE: {rmse:.2f}")
print(f"ANN with Indicators - R² Score: {r2:.4f}")

# Plot results
plt.figure(figsize=(12, 6))
plt.plot(y_actual, label='Actual', linewidth=2)
plt.plot(y_pred, label='Predicted', linewidth=2)
plt.title("Predicted vs Actual AAPL Prices (Test Set)")
plt.xlabel("Time Index")
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("ann_predicted_vs_actual.png")
plt.show()
# Out:
# C:\Users\harri\AppData\Local\Temp\ipykernel_24604\2197638192.py:22: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("AAPL", start="2018-01-01", end="2025-08-01")
# [*********************100%***********************]  1 of 1 completed
# c:\Users\harri\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ANN with Indicators - RMSE: 4.80
# ANN with Indicators - R² Score: 0.9563

# %%
# !pip install numpy pandas yfinance matplotlib scikit-learn tensorflow ta
# Out:
# Collecting numpy
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting pandas
#   Using cached pandas-2.3.1-cp310-cp310-win_amd64.whl (11.3 MB)
# Collecting yfinance
#   Using cached yfinance-0.2.65-py2.py3-none-any.whl (119 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.5-cp310-cp310-win_amd64.whl (8.1 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.7.1-cp310-cp310-win_amd64.whl (8.9 MB)
# Collecting tensorflow
#   Using cached tensorflow-2.19.0-cp310-cp310-win_amd64.whl (375.7 MB)
# Collecting ta
#   Using cached ta-0.11.0-py3-none-any.whl
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\harri\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Collecting beautifulsoup4>=4.11.1
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\harri\appdata\roaming\python\python310\site-packages (from yfinance) (4.3.8)
# Collecting websockets>=13.0
#   Using cached websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Collecting protobuf>=3.19.0
#   Downloading protobuf-6.31.1-cp310-abi3-win_amd64.whl (435 kB)
#      -------------------------------------- 435.3/435.3 kB 3.0 MB/s eta 0:00:00
# Collecting peewee>=3.16.2
#   Using cached peewee-3.18.2-py3-none-any.whl
# Collecting multitasking>=0.0.7
#   Using cached multitasking-0.0.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting curl_cffi>=0.7
#   Using cached curl_cffi-0.12.0-cp39-abi3-win_amd64.whl (1.6 MB)
# Collecting requests>=2.31
#   Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Collecting frozendict>=2.3.4
#   Using cached frozendict-2.4.6-cp310-cp310-win_amd64.whl (37 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\harri\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-win_amd64.whl (221 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.59.0-cp310-cp310-win_amd64.whl (2.3 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-win_amd64.whl (71 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting pillow>=8
#   Using cached pillow-11.3.0-cp310-cp310-win_amd64.whl (7.0 MB)
# Collecting scipy>=1.8.0
#   Using cached scipy-1.15.3-cp310-cp310-win_amd64.whl (41.3 MB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.1-py3-none-any.whl (307 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting wrapt>=1.11.0
#   Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Collecting flatbuffers>=24.3.25
#   Using cached flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.74.0-cp310-cp310-win_amd64.whl (4.5 MB)
# Requirement already satisfied: six>=1.12.0 in c:\users\harri\appdata\roaming\python\python310\site-packages (from tensorflow) (1.17.0)
# Collecting protobuf>=3.19.0
#   Using cached protobuf-5.29.5-cp310-abi3-win_amd64.whl (434 kB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting keras>=3.5.0
#   Using cached keras-3.11.1-py3-none-any.whl (1.4 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.31.0-cp310-cp310-win_amd64.whl (1.5 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\harri\appdata\roaming\python\python310\site-packages (from tensorflow) (4.14.1)
# Collecting ml-dtypes<1.0.0,>=0.5.1
#   Using cached ml_dtypes-0.5.3-cp310-cp310-win_amd64.whl (206 kB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.3.1-py3-none-any.whl (135 kB)
# Requirement already satisfied: setuptools in c:\users\harri\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (65.5.0)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting h5py>=3.11.0
#   Using cached h5py-3.14.0-cp310-cp310-win_amd64.whl (2.9 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Collecting tensorboard~=2.19.0
#   Using cached tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
# Collecting numpy
#   Using cached numpy-2.1.3-cp310-cp310-win_amd64.whl (12.9 MB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting wheel<1.0,>=0.23.0
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.7-py3-none-any.whl (36 kB)
# Collecting certifi>=2024.2.2
#   Using cached certifi-2025.8.3-py3-none-any.whl (161 kB)
# Collecting cffi>=1.12.0
#   Using cached cffi-1.17.1-cp310-cp310-win_amd64.whl (181 kB)
# Collecting optree
#   Using cached optree-0.17.0-cp310-cp310-win_amd64.whl (304 kB)
# Collecting namex
#   Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Collecting rich
#   Using cached rich-14.1.0-py3-none-any.whl (243 kB)
# Collecting charset_normalizer<4,>=2
#   Using cached charset_normalizer-3.4.2-cp310-cp310-win_amd64.whl (105 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Collecting markdown>=2.6.8
#   Using cached markdown-3.8.2-py3-none-any.whl (106 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-3.0.2-cp310-cp310-win_amd64.whl (15 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\harri\appdata\roaming\python\python310\site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: pytz, peewee, namex, multitasking, libclang, flatbuffers, wrapt, wheel, websockets, urllib3, tzdata, threadpoolctl, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, soupsieve, pyparsing, pycparser, protobuf, pillow, optree, opt-einsum, numpy, mdurl, MarkupSafe, markdown, kiwisolver, joblib, idna, grpcio, google-pasta, gast, frozendict, fonttools, cycler, charset_normalizer, certifi, absl-py, werkzeug, scipy, requests, pandas, ml-dtypes, markdown-it-py, h5py, contourpy, cffi, beautifulsoup4, astunparse, tensorboard, ta, scikit-learn, rich, matplotlib, curl_cffi, yfinance, keras, tensorflow
#   Running setup.py install for multitasking: started
#   Running setup.py install for multitasking: finished with status 'done'
# Successfully installed MarkupSafe-3.0.2 absl-py-2.3.1 astunparse-1.6.3 beautifulsoup4-4.13.4 certifi-2025.8.3 cffi-1.17.1 charset_normalizer-3.4.2 contourpy-1.3.2 curl_cffi-0.12.0 cycler-0.12.1 flatbuffers-25.2.10 fonttools-4.59.0 frozendict-2.4.6 gast-0.6.0 google-pasta-0.2.0 grpcio-1.74.0 h5py-3.14.0 idna-3.10 joblib-1.5.1 keras-3.11.1 kiwisolver-1.4.8 libclang-18.1.1 markdown-3.8.2 markdown-it-py-3.0.0 matplotlib-3.10.5 mdurl-0.1.2 ml-dtypes-0.5.3 multitasking-0.0.12 namex-0.1.0 numpy-2.1.3 opt-einsum-3.4.0 optree-0.17.0 pandas-2.3.1 peewee-3.18.2 pillow-11.3.0 protobuf-5.29.5 pycparser-2.22 pyparsing-3.2.3 pytz-2025.2 requests-2.32.4 rich-14.1.0 scikit-learn-1.7.1 scipy-1.15.3 soupsieve-2.7 ta-0.11.0 tensorboard-2.19.0 tensorboard-data-server-0.7.2 tensorflow-2.19.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-3.1.0 threadpoolctl-3.6.0 tzdata-2025.2 urllib3-2.5.0 websockets-15.0.1 werkzeug-3.1.3 wheel-0.45.1 wrapt-1.17.2 yfinance-0.2.65
#   DEPRECATION: multitasking is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#
# [notice] A new release of pip available: 22.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
